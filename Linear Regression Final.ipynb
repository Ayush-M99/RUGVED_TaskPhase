# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
lr =pd.read_csv(r"C:\Users\Ayush Mishra\Downloads\rugvedlin.csv")

# %%
lr
# Out:
#           carat        cut color clarity      depth      table         x  \
# 0      0.544971      Ideal     E     SI1  63.911017  52.575829  5.447452
# 1      2.073682    Premium     J     SI1  67.642925  57.660288  6.266665
# 2      0.606198    Premium     G     VS1  55.617310  60.388787  6.800151
# 3      0.695397    Premium     G     SI2  60.587811  71.325721  5.366931
# 4      0.282651      Ideal     E    VVS2  68.970056  54.372123  4.920104
# ...         ...        ...   ...     ...        ...        ...       ...
# 11995  0.251768    Premium     E     VS1  69.674513  52.790228  5.657402
# 11996  1.729415    Premium     H     SI1  56.191121  48.024573  6.725585
# 11997  2.252697  Very Good     I     SI2  64.007494  63.641838  8.510526
# 11998  0.139030  Very Good     D     VS2  64.885328  55.383459  2.799799
# 11999  0.320988      Ideal     G      IF  68.921055  62.357899  4.970371
#
#               y         z   price
# 0      4.053076  3.701485   3.558
# ...

# %%
#Check missing values
missing_values = lr.isnull().sum()
print("Missing values by columns:\n", missing_values)

#remove rows
lr.dropna()

#remove duplicate rows
lr.drop_duplicates()

#fill missing data
lr.fillna(method='ffill')

lr.interpolate()
# Out:
# Missing values by columns:
#  carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64
#           carat        cut color clarity      depth      table         x  \
# 0      0.544971      Ideal     E     SI1  63.911017  52.575829  5.447452
# 1      2.073682    Premium     J     SI1  67.642925  57.660288  6.266665
# 2      0.606198    Premium     G     VS1  55.617310  60.388787  6.800151
# 3      0.695397    Premium     G     SI2  60.587811  71.325721  5.366931
# 4      0.282651      Ideal     E    VVS2  68.970056  54.372123  4.920104
# ...         ...        ...   ...     ...        ...        ...       ...
# 11995  0.251768    Premium     E     VS1  69.674513  52.790228  5.657402
# 11996  1.729415    Premium     H     SI1  56.191121  48.024573  6.725585
# 11997  2.252697  Very Good     I     SI2  64.007494  63.641838  8.510526
# ...

# %%
lr
# Out:
#           carat        cut color clarity      depth      table         x  \
# 0      0.544971      Ideal     E     SI1  63.911017  52.575829  5.447452
# 1      2.073682    Premium     J     SI1  67.642925  57.660288  6.266665
# 2      0.606198    Premium     G     VS1  55.617310  60.388787  6.800151
# 3      0.695397    Premium     G     SI2  60.587811  71.325721  5.366931
# 4      0.282651      Ideal     E    VVS2  68.970056  54.372123  4.920104
# ...         ...        ...   ...     ...        ...        ...       ...
# 11995  0.251768    Premium     E     VS1  69.674513  52.790228  5.657402
# 11996  1.729415    Premium     H     SI1  56.191121  48.024573  6.725585
# 11997  2.252697  Very Good     I     SI2  64.007494  63.641838  8.510526
# 11998  0.139030  Very Good     D     VS2  64.885328  55.383459  2.799799
# 11999  0.320988      Ideal     G      IF  68.921055  62.357899  4.970371
#
#               y         z   price
# 0      4.053076  3.701485   3.558
# ...

# %%
X = lr[["depth", "carat"]].copy()
y = lr[["price"]].copy()

# %%
X
# Out:
#            depth     carat
# 0      63.911017  0.544971
# 1      67.642925  2.073682
# 2      55.617310  0.606198
# 3      60.587811  0.695397
# 4      68.970056  0.282651
# ...          ...       ...
# 11995  69.674513  0.251768
# 11996  56.191121  1.729415
# 11997  64.007494  2.252697
# 11998  64.885328  0.139030
# 11999  68.921055  0.320988
#
# [12000 rows x 2 columns]

# %%
y
# Out:
#         price
# 0       3.558
# 1      24.738
# 2       3.630
# 3       4.218
# 4       1.578
# ...       ...
# 11995   1.628
# 11996  15.508
# 11997  20.018
# 11998   0.746
# 11999   1.660
#
# [12000 rows x 1 columns]

# %%
X["intercept"] = 1

# %%
X = X[["intercept", "depth", "carat"]]

# %%
X
# Out:
#        intercept      depth     carat
# 0              1  63.911017  0.544971
# 1              1  67.642925  2.073682
# 2              1  55.617310  0.606198
# 3              1  60.587811  0.695397
# 4              1  68.970056  0.282651
# ...          ...        ...       ...
# 11995          1  69.674513  0.251768
# 11996          1  56.191121  1.729415
# 11997          1  64.007494  2.252697
# 11998          1  64.885328  0.139030
# 11999          1  68.921055  0.320988
#
# [12000 rows x 3 columns]

# %%
X_T = X.T

# %%
X_T
# Out:
#                0          1          2          3          4         5      \
# intercept   1.000000   1.000000   1.000000   1.000000   1.000000   1.00000
# depth      63.911017  67.642925  55.617310  60.587811  68.970056  58.61093
# carat       0.544971   2.073682   0.606198   0.695397   0.282651   0.20625
#
#                6          7          8          9      ...      11990  \
# intercept   1.000000   1.000000   1.000000   1.000000  ...   1.000000
# depth      64.427180  65.351765  56.247125  56.100211  ...  62.562104
# carat       0.315427   0.272113   0.448917   0.334541  ...   0.911926
#
#                11991      11992      11993      11994      11995      11996  \
# intercept   1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
# depth      57.001672  59.611771  65.628466  71.775169  69.674513  56.191121
# carat       0.704168   1.158681   0.606313   0.458307   0.251768   1.729415
#
#                11997      11998      11999
# ...

# %%
B = np.linalg.inv(X_T @ X) @ X_T @ y

# %%
B
# Out:
#        price
# 0  -3.234830
# 1  -0.011952
# 2  14.860162

# %%
B.index = X.columns

# %%
B
# Out:
#                price
# intercept  -3.234830
# depth      -0.011952
# carat      14.860162

# %%
predictions = X @ B

# %%
predictions
# Out:
#            price
# 0       4.099657
# 1      26.771953
# 2       5.108629
# 3       6.374727
# 4       0.141069
# ...          ...
# 11995  -0.326270
# 11996  21.792956
# 11997  29.475590
# 11998  -1.944339
# 11999   0.711354
#
# [12000 rows x 1 columns]

# %%
SSR = ((y - predictions) ** 2).sum()

# %%
SSR
# Out:
# price    144345.465105
# dtype: float64

# %%
TSS = ((y - y.mean()) ** 2).sum()

# %%
TSS
# Out:
# price    768065.749149
# dtype: float64

# %%
R2 = 1 - (SSR / TSS)

# %%
R2
# Out:
# price    0.812066
# dtype: float64

# %%
# Visaulize results
fig, ax = plt.subplots()
ax.scatter(lr["carat"], lr["price"], label="Actual Prices", s=10 )
ax.plot(lr["carat"], predictions, label="Predicted Prices", color="red")
ax.set_xlabel("Carat")
ax.set_ylabel("Price")
ax.set_title("Linear Regression Model for Price vs Carat")
ax.legend()
plt.show()
